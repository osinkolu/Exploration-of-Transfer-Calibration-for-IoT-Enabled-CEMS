# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
alpha = pd.read_csv("alpha.csv").drop(["CO2", "CO", "MG811_Digital","MQ7_Digital"], axis = 1)
beta = pd.read_csv("beta.csv").drop(["CO2", "CO", "MG811_Digital","MQ7_Digital"], axis = 1)
charlie = pd.read_csv("charlie.csv").drop(["CO2", "CO", "MG811_Digital","MQ7_Digital"], axis = 1)

# %%
alpha
# Out:
#                created_at  Temperature  Humidity  MQ7_analog  MQ9_analog  \
# 0     2023-05-01 03:29:00        31.40     63.38      5546.0      1281.0
# 1     2023-05-01 03:30:00        31.44     63.20      5526.0      1281.0
# 2     2023-05-01 03:31:00        31.50     63.07      5463.0      1276.0
# 3     2023-05-01 03:32:00        31.49     63.08      5370.0      1272.0
# 4     2023-05-01 03:33:00        31.51     62.88      5306.0      1264.0
# ...                   ...          ...       ...         ...         ...
# 2809  2023-06-29 14:43:00        30.62     67.28      2394.0      3496.0
# 2810  2023-06-29 14:44:00        30.61     66.78      2384.0      3473.0
# 2811  2023-06-29 14:45:00        30.76     70.07      2411.0      3530.0
# 2812  2023-06-29 14:46:00        30.81     68.33      2399.0      3484.0
# 2813  2023-06-29 15:40:00        31.62     70.53      2380.0      3460.0
#
#       MG811_analog  MQ135_analog
# 0           6775.0        1308.0
# ...

# %%
beta
# Out:
#                created_at  Temperature  Humidity  MQ7_analog  MQ9_analog  \
# 0     2023-05-01 03:30:00        27.79     74.39      3122.0      3854.0
# 1     2023-05-01 03:31:00        27.79     74.29      3096.0      3835.0
# 2     2023-05-01 03:32:00        27.81     74.28      3105.0      3841.0
# 3     2023-05-01 03:33:00        27.79     74.24      3112.0      3847.0
# 4     2023-05-01 03:34:00        27.80     74.24      3105.0      3832.0
# ...                   ...          ...       ...         ...         ...
# 2919  2023-06-29 14:43:00        29.29     68.17      3251.0      4804.0
# 2920  2023-06-29 14:44:00        29.33     68.95      3211.0      4765.0
# 2921  2023-06-29 14:45:00        29.39     71.75      3241.0      4771.0
# 2922  2023-06-29 14:46:00        29.47     71.06      3215.0      4746.0
# 2923  2023-06-29 15:40:00        30.29     69.02      3143.0      4674.0
#
#       MG811_analog  MQ135_analog
# 0           3867.0        3506.0
# ...

# %%
charlie
# Out:
#                created_at  Temperature  Humidity  MQ7_analog  MQ9_analog  \
# 0     2023-05-01 03:29:00        28.58     71.84      6011.0      6188.0
# 1     2023-05-01 03:30:00        28.59     71.82      5978.0      6168.0
# 2     2023-05-01 03:31:00        28.58     71.79      5978.0      6143.0
# 3     2023-05-01 03:32:00        28.55     71.99      5989.0      6127.0
# 4     2023-05-01 03:33:00        28.53     71.83      5968.0      6130.0
# ...                   ...          ...       ...         ...         ...
# 2856  2023-06-29 14:43:00        30.42     66.32      3374.0      3243.0
# 2857  2023-06-29 14:44:00        30.26     67.41      3272.0      3204.0
# 2858  2023-06-29 14:45:00        30.39     68.74      3358.0      3249.0
# 2859  2023-06-29 14:46:00        30.67     69.19      3337.0      3232.0
# 2860  2023-06-29 15:40:00        31.42     67.83      3367.0      3282.0
#
#       MG811_analog  MQ135_analog
# 0           4784.0        4420.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already loaded the dataframes 'alpha' and 'beta'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, beta, on='created_at', suffixes=('_alpha', '_beta'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Check for a linear relationship between the desired columns and plot the correlations
desired_columns = ['Temperature', 'Humidity', 'MQ7_analog', 'MQ9_analog', 'MG811_analog', 'MQ135_analog']


for column in desired_columns:
    correlation = merged_df[f"{column}_alpha"].corr(merged_df[f"{column}_beta"])
    print(f"Correlation between {column} in alpha and beta data: {correlation}")
    
    
    
# Calculate and plot the correlation for each column
plt.figure(figsize=(10, 6))
for column in desired_columns:
    correlation = merged_df[f"{column}_alpha"].corr(merged_df[f"{column}_beta"])
    plt.scatter(merged_df[f"{column}_alpha"], merged_df[f"{column}_beta"], label=f"Correlation: {correlation:.2f}")
    
plt.xlabel("Alpha Data")
plt.ylabel("Beta Data")
plt.title("Correlation between Alpha and Beta Data")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Correlation between Temperature in alpha and beta data: 0.64926573539417
# Correlation between Humidity in alpha and beta data: 0.6764708348667954
# Correlation between MQ7_analog in alpha and beta data: 0.4334419583183424
# Correlation between MQ9_analog in alpha and beta data: 0.8566664830064897
# Correlation between MG811_analog in alpha and beta data: -0.039641154625926135
# Correlation between MQ135_analog in alpha and beta data: 0.20644576499665682

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already loaded the dataframes 'alpha' and 'beta'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, beta, on='created_at', suffixes=('_alpha', '_beta'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Create the scatter plot comparing "MG811_analog" in alpha vs beta
plt.figure(figsize=(15, 12))
sns.scatterplot(data=merged_df, x='MG811_analog_alpha', y='MG811_analog_beta', hue=merged_df.index, palette='coolwarm')
plt.xlabel('MG811_analog (Alpha)')
plt.ylabel('MG811_analog (Beta)')
plt.title('Comparison of MG811_analog in Alpha vs Beta')
plt.grid(True)

# Add a legend
plt.legend(title='Dataframe', loc='best', labels=['Alpha', 'Beta'])

# Add a 45-degree reference line
plt.plot([min(merged_df['MG811_analog_alpha']), max(merged_df['MG811_analog_alpha'])],
         [min(merged_df['MG811_analog_alpha']), max(merged_df['MG811_analog_alpha'])],
         color='gray', linestyle='dashed')

# Save the plot as an image
plt.savefig('Comparison of MG811_analog in Alpha vs Beta', bbox_inches='tight')


plt.show()

# %%
merged_df
# Out:
#                created_at  Temperature_alpha  Humidity_alpha  \
# 0     2023-05-01 03:30:00              31.44           63.20
# 1     2023-05-01 03:31:00              31.50           63.07
# 2     2023-05-01 03:32:00              31.49           63.08
# 3     2023-05-01 03:33:00              31.51           62.88
# 4     2023-05-01 03:34:00              31.53           62.92
# ...                   ...                ...             ...
# 2778  2023-06-29 14:43:00              30.62           67.28
# 2779  2023-06-29 14:44:00              30.61           66.78
# 2780  2023-06-29 14:45:00              30.76           70.07
# 2781  2023-06-29 14:46:00              30.81           68.33
# 2782  2023-06-29 15:40:00              31.62           70.53
#
#       MQ7_analog_alpha  MQ9_analog_alpha  MG811_analog_alpha  \
# 0               5526.0            1281.0              6998.0
# 1               5463.0            1276.0              6881.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Assuming you have already loaded the dataframes 'alpha' and 'beta'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, beta, on='created_at', suffixes=('_alpha', '_beta'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Get the list of sensor features
sensor_features = ['Temperature', 'Humidity', 'MQ7_analog', 'MQ9_analog', 'MG811_analog', 'MQ135_analog']

# Create a scatter plot for each sensor
plt.figure(figsize=(15, 12))
for feature in sensor_features:
    plt.subplot(3, 3, sensor_features.index(feature) + 1)
    sns.scatterplot(data=merged_df, x=f'{feature}_alpha', y=f'{feature}_beta', palette='coolwarm')
    plt.xlabel(f'{feature} (Alpha)')
    plt.ylabel(f'{feature} (Beta)')
    plt.title(f'Comparison of {feature} in Alpha vs Beta')
    plt.grid(True)

    # Add a 45-degree reference line
    plt.plot([min(merged_df[f'{feature}_alpha']), max(merged_df[f'{feature}_alpha'])],
             [min(merged_df[f'{feature}_alpha']), max(merged_df[f'{feature}_alpha'])],
             color='gray', linestyle='dashed')

# Custom legend for 'Alpha' and 'Beta'
alpha_patch = mpatches.Patch(color=sns.color_palette('coolwarm')[0], label='Alpha')
beta_patch = mpatches.Patch(color=sns.color_palette('coolwarm')[1], label='Beta')
plt.legend(handles=[alpha_patch, beta_patch], title='Dataframe', loc='best')

plt.tight_layout()

# Save the plot as an image
plt.savefig('Comparison of Sensors in Alpha vs Beta', bbox_inches='tight')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Assuming you have already loaded the dataframes 'alpha' and 'charlie'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, charlie, on='created_at', suffixes=('_alpha', '_charlie'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Get the list of sensor features
sensor_features = ['Temperature', 'Humidity', 'MQ7_analog', 'MQ9_analog', 'MG811_analog', 'MQ135_analog']

# Create a scatter plot for each sensor
plt.figure(figsize=(15, 12))
for feature in sensor_features:
    plt.subplot(3, 3, sensor_features.index(feature) + 1)
    sns.scatterplot(data=merged_df, x=f'{feature}_alpha', y=f'{feature}_charlie', palette='coolwarm')
    plt.xlabel(f'{feature} (Alpha)')
    plt.ylabel(f'{feature} (charlie)')
    plt.title(f'Comparison of {feature} in Alpha vs charlie')
    plt.grid(True)

    # Add a 45-degree reference line
    plt.plot([min(merged_df[f'{feature}_alpha']), max(merged_df[f'{feature}_alpha'])],
             [min(merged_df[f'{feature}_alpha']), max(merged_df[f'{feature}_alpha'])],
             color='gray', linestyle='dashed')

# Custom legend for 'Alpha' and 'charlie'
alpha_patch = mpatches.Patch(color=sns.color_palette('coolwarm')[0], label='Alpha')
charlie_patch = mpatches.Patch(color=sns.color_palette('coolwarm')[1], label='charlie')
plt.legend(handles=[alpha_patch, charlie_patch], title='Dataframe', loc='best')

plt.tight_layout()

# Save the plot as an image
plt.savefig('Comparison of Sensors in Alpha vs charlie', bbox_inches='tight')

plt.show()

# %%
import pandas as pd
from scipy.stats import pearsonr

# Assuming you have already loaded the dataframes 'alpha' and 'beta'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, beta, on='created_at', suffixes=('_alpha', '_beta'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Calculate the correlation coefficient and p-value
corr_coefficient, p_value = pearsonr(merged_df['MG811_analog_alpha'], merged_df['MG811_analog_beta'])

# Display the results
print(f"Correlation coefficient: {corr_coefficient:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Correlation coefficient: -0.0396
# P-value: 0.0365

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already loaded the dataframes 'alpha' and 'beta'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, beta, on='created_at', suffixes=('_alpha', '_beta'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Create a pair plot with scatter plots for each feature
sns.pairplot(merged_df, vars=['Temperature_alpha', 'Humidity_alpha', 'MQ7_analog_alpha', 'MQ9_analog_alpha', 'MG811_analog_alpha', 'MQ135_analog_alpha'], diag_kind='kde')
plt.suptitle("Scatter Plots for Each Feature")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already loaded the dataframes 'alpha' and 'beta'

# Merge the dataframes based on the 'created_at' column
merged_df = pd.merge(alpha, beta, on='created_at', suffixes=('_alpha', '_beta'))

# Drop rows with missing values resulting from the merge
merged_df.dropna(inplace=True)

# Get the desired columns with suffixes for the correlation matrix
desired_columns_alpha = ['Temperature_alpha', 'Humidity_alpha', 'MQ7_analog_alpha', 'MQ9_analog_alpha', 'MG811_analog_alpha', 'MQ135_analog_alpha']
desired_columns_beta = ['Temperature_beta', 'Humidity_beta', 'MQ7_analog_beta', 'MQ9_analog_beta', 'MG811_analog_beta', 'MQ135_analog_beta']

# Calculate the correlation matrix
correlation_matrix = merged_df[desired_columns_alpha].corrwith(merged_df[desired_columns_beta])

# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix.to_frame(), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title("Correlation Heatmap (Alpha vs Beta)")
plt.show()

# %%
merged_df.columns
# Out:
# Index(['created_at', 'Temperature_alpha', 'Humidity_alpha', 'MQ7_analog_alpha',
#        'MQ9_analog_alpha', 'MG811_analog_alpha', 'MQ135_analog_alpha',
#        'Temperature_beta', 'Humidity_beta', 'MQ7_analog_beta',
#        'MQ9_analog_beta', 'MG811_analog_beta', 'MQ135_analog_beta'],
#       dtype='object')

# %%
merged_df
# Out:
#                created_at  Temperature_alpha  Humidity_alpha  \
# 0     2023-05-01 03:30:00              31.44           63.20
# 1     2023-05-01 03:31:00              31.50           63.07
# 2     2023-05-01 03:32:00              31.49           63.08
# 3     2023-05-01 03:33:00              31.51           62.88
# 4     2023-05-01 03:34:00              31.53           62.92
# ...                   ...                ...             ...
# 2778  2023-06-29 14:43:00              30.62           67.28
# 2779  2023-06-29 14:44:00              30.61           66.78
# 2780  2023-06-29 14:45:00              30.76           70.07
# 2781  2023-06-29 14:46:00              30.81           68.33
# 2782  2023-06-29 15:40:00              31.62           70.53
#
#       MQ7_analog_alpha  MQ9_analog_alpha  MG811_analog_alpha  \
# 0               5526.0            1281.0              6998.0
# 1               5463.0            1276.0              6881.0
# ...

# %%
data = data.drop(columns=["created_at","MG811_Digital","MQ7_Digital"])

#Drop rows where the value of 'column_name' is 0
#data = data.loc[data['CO'] != 0]

# %%
"""# Assuming 'data' is the DataFrame and 'label_column' is the name of the label column
label_column = 'CO'

# Calculate the number of zeros to keep (20% of total zeros)
total_zeros = (data[label_column] == 0).sum()
zeros_to_keep = int(0.2 * total_zeros)

# Get the indices of the zero values
zero_indices = data.index[data[label_column] == 0].tolist()

# Keep 20% of the zero values randomly
import random
zero_indices_to_keep = random.sample(zero_indices, zeros_to_keep)

# Create a new DataFrame with only the selected zero values and non-zero values
data_filtered = data.loc[zero_indices_to_keep]
non_zero_data = data[data[label_column] != 0]
data_filtered = pd.concat([data_filtered, non_zero_data])

# The data_filtered DataFrame now contains 20% of the zero values and all non-zero values"""
# Out:
# "# Assuming 'data' is the DataFrame and 'label_column' is the name of the label column\nlabel_column = 'CO'\n\n# Calculate the number of zeros to keep (20% of total zeros)\ntotal_zeros = (data[label_column] == 0).sum()\nzeros_to_keep = int(0.2 * total_zeros)\n\n# Get the indices of the zero values\nzero_indices = data.index[data[label_column] == 0].tolist()\n\n# Keep 20% of the zero values randomly\nimport random\nzero_indices_to_keep = random.sample(zero_indices, zeros_to_keep)\n\n# Create a new DataFrame with only the selected zero values and non-zero values\ndata_filtered = data.loc[zero_indices_to_keep]\nnon_zero_data = data[data[label_column] != 0]\ndata_filtered = pd.concat([data_filtered, non_zero_data])\n\n# The data_filtered DataFrame now contains 20% of the zero values and all non-zero values"

# %%
alpha = alpha.sample(frac=1).reset_index(drop=True)
beta = beta.sample(frac=1).reset_index(drop=True)
charlie = charlie.sample(frac=1).reset_index(drop=True)

# %%
#data_filtered.reset_index(drop=True)

# %%
data.head()
# Out:
#    Temperature  Humidity  MQ7_analog  MQ9_analog  MG811_analog  MQ135_analog  \
# 0    31.415000    63.390      5596.5      1288.0        6870.5        1320.0
# 1    31.445000    63.295      5538.0      1282.5        7035.5        1315.0
# 2    31.500000    63.115      5482.5      1276.0        6906.0        1311.5
# 3    31.510000    63.125      5396.5      1272.5        6879.0        1307.0
# 4    31.523333    62.990      5336.0      1266.0        6895.0        1302.0
#
#      CO2   CO
# 0  618.5  0.0
# 1  617.5  0.0
# 2  610.0  0.0
# 3  604.0  0.0
# 4  609.0  0.0

# %%
data.CO.sum()
# Out:
# 10303.583333333334

# %%
# Create a correlation matrix for the DataFrame
correlation_matrix = data.drop(columns=["CO2"]).corr()

# Plot the correlation heatmap for the 'CO2' column
plt.figure(figsize=(10, 12))
sns.heatmap(correlation_matrix[['CO']].sort_values(by='CO', ascending=False),
            annot=True, cmap='coolwarm', vmin=-1, vmax=1,cbar_kws={"orientation": "horizontal"})
plt.title('Correlation Heatmap for CO')

# Save the plot as an image
plt.savefig('Alpha_co_correlation_plot.png', bbox_inches='tight')

plt.show()

# %%
data.isnull().sum()
# Out:
# Temperature     0
# Humidity        0
# MQ7_analog      0
# MQ9_analog      0
# MG811_analog    0
# MQ135_analog    0
# CO2             0
# CO              0
# dtype: int64

# %%
target = data.CO
data = data.drop(["CO2", "CO"], axis = 1)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler,MaxAbsScaler,RobustScaler

# Assuming you have your dataframe 'df' with the features to be scaled

# Step 1: Create a MinMaxScaler object
scaler = MinMaxScaler()

# Step 2: Fit the scaler to the data and transform the data
scaled_data = scaler.fit_transform(data)

# Step 3: Convert the scaled data back to a dataframe (optional)
data = pd.DataFrame(scaled_data, columns=data.columns)

# %%
data.isnull().sum()
# Out:
# Temperature     0
# Humidity        0
# MQ7_analog      0
# MQ9_analog      0
# MG811_analog    0
# MQ135_analog    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2814 entries, 0 to 2813
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Temperature   2814 non-null   float64
#  1   Humidity      2814 non-null   float64
#  2   MQ7_analog    2814 non-null   float64
#  3   MQ9_analog    2814 non-null   float64
#  4   MG811_analog  2814 non-null   float64
#  5   MQ135_analog  2814 non-null   float64
# dtypes: float64(6)
# memory usage: 132.0 KB

# %%
data.describe()
# Out:
#        Temperature     Humidity   MQ7_analog   MQ9_analog  MG811_analog  \
# count  2814.000000  2814.000000  2814.000000  2814.000000   2814.000000
# mean      0.673446     0.423204     0.174551     0.164362      0.445682
# std       0.199422     0.216224     0.151091     0.146541      0.203682
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.654810     0.266124     0.067494     0.059490      0.276900
# 50%       0.686338     0.367335     0.134115     0.093799      0.467890
# 75%       0.788197     0.582457     0.229415     0.254647      0.583460
# max       1.000000     1.000000     1.000000     1.000000      1.000000
#
#        MQ135_analog
# count   2814.000000
# mean       0.308914
# std        0.165111
# min        0.000000
# 25%        0.201049
# 50%        0.339308
# 75%        0.396824
# max        1.000000

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import lightgbm as lgb
import xgboost as xgb
import catboost as cb
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor

# Assuming you have the data loaded in 'data' and the labels in 'target'

# Step 1: Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# Step 2: Build regression models using k-fold cross-validation
models = {
    "LGBM": lgb.LGBMRegressor(),
    "XGBoost": xgb.XGBRegressor(),
    "CatBoost": cb.CatBoostRegressor(silent=True, n_estimators=100),
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "SVR": SVR(),
    "Linear Regression": LinearRegression(),
    "MLP": MLPRegressor(hidden_layer_sizes=(100, 50, 10), max_iter=500, random_state=42)
}

eval_metrics = {
    "MAE": mean_absolute_error,
    "RMSE": lambda y_true, y_pred: np.sqrt(mean_squared_error(y_true, y_pred)),
    "R2": r2_score,
    "MSE": mean_squared_error
}

results = []

for model_name, model in models.items():
    cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_absolute_error')
    cv_mae = -cv_scores.mean()  # Since cross_val_score returns negative MAE

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    model_results = {"Model": model_name, "CrossVal MAE": cv_mae}

    for metric_name, metric_func in eval_metrics.items():
        metric_value = metric_func(y_test, y_pred)
        model_results[metric_name] = metric_value

    results.append(model_results)

# Step 3: Save the results in a DataFrame
results_df = pd.DataFrame(results)

results_df
# Out:
#                Model  CrossVal MAE       MAE       RMSE        R2         MSE
# 0               LGBM      4.660090  2.705709  20.138614  0.183946  405.563783
# 1            XGBoost      2.606370  1.147311  15.847454  0.494666  251.141794
# 2           CatBoost      3.078072  1.911154  20.619699  0.144492  425.171986
# 3      Random Forest      3.143666  1.529953  16.574907  0.447208  274.727548
# 4  Gradient Boosting      3.263490  1.223592  11.940161  0.713133  142.567446
# 5                SVR      4.232002  1.448497  22.132193  0.014383  489.833981
# 6  Linear Regression     11.235306  8.034397  21.888342  0.035982  479.099505
# 7                MLP      3.674367  1.567945  13.099535  0.654720  171.597813

# %%
# Step 4: Plot bar charts for each metric
metrics_to_plot = list(eval_metrics.keys())

for metric in metrics_to_plot:
    plt.figure(figsize=(8, 6))
    sorted_results = results_df.sort_values(metric, ascending=True)
    bars = plt.bar(sorted_results["Model"], sorted_results[metric])
    plt.xlabel("Models")
    plt.ylabel(metric)
    plt.title(f"{metric} Comparison")
    plt.xticks(rotation=45, ha='right')
    
    # Annotate the bars with their corresponding metric values
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2., height, f"{height:.2f}",
                 ha='center', va='bottom')
    
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have the data loaded in 'data' and the labels in 'target'

# Step 1: Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# Step 2: Build the Random Forest regression model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

# Step 3: Make predictions on the test set
y_pred = rf_model.predict(X_test)

# Step 4: Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Step 5: Create a scatter plot of actual vs. predicted values with a reference line
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--', label='45-degree line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Random Forest Regressor - Actual vs. Predicted')
plt.text(0.05, 0.9, f'MSE: {mse:.2f}', transform=plt.gca().transAxes)
plt.text(0.05, 0.85, f'R2 Score: {r2:.2f}', transform=plt.gca().transAxes)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor

# Assuming you have the data loaded in 'data' and the labels in 'target'

# Step 1: Build the Random Forest regression model
rf_model = RandomForestRegressor()
rf_model.fit(data, target)

# Step 2: Get feature importances
feature_importance = rf_model.feature_importances_

# Step 3: Create a DataFrame to store feature importances
feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

# Step 4: Sort the features by importance in descending order
feature_importance_df = feature_importance_df.sort_values('Importance', ascending=False)

# Step 5: Plot the feature importance as a bar chart using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Random Forest Feature Importance')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

# Assuming you have the data loaded in 'data' and the labels in 'target'

# Step 1: Build the LGBM regression model
lgb_model = lgb.LGBMRegressor()
lgb_model.fit(data, target)

# Step 2: Get feature importances
feature_importance = lgb_model.feature_importances_

# Step 3: Create a DataFrame to store feature importances
feature_importance_df = pd.DataFrame({'Feature': data.columns, 'Importance': feature_importance})

# Step 4: Sort the features by importance in descending order
feature_importance_df = feature_importance_df.sort_values('Importance', ascending=False)

# Step 5: Plot the feature importance as a bar chart using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('LGBM Feature Importance')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Assuming you have the data loaded in 'data' and the labels in 'target'

# Step 1: Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# Step 2: Initialize the Random Forest regression model
rf_model = RandomForestRegressor()

# Step 3: Create lists to store training and validation errors
train_errors, val_errors = [], []

# Step 4: Vary the size of the training set and compute errors
min_samples = 10  # Minimum size of the training set
step_size = 50    # Increase the training set size by this step

for i in range(min_samples, len(X_train), step_size):
    X_train_subset, _, y_train_subset, _ = train_test_split(X_train, y_train, train_size=i, random_state=42)
    
    rf_model.fit(X_train_subset, y_train_subset)
    
    # Calculate training and validation errors
    y_train_pred = rf_model.predict(X_train_subset)
    y_val_pred = rf_model.predict(X_test)
    
    train_error = mean_squared_error(y_train_subset, y_train_pred)
    val_error = mean_squared_error(y_test, y_val_pred)
    
    train_errors.append(train_error)
    val_errors.append(val_error)

# Step 5: Plot the learning curve
plt.figure(figsize=(8, 6))
plt.plot(range(min_samples, len(X_train), step_size), train_errors, label='Training Error')
plt.plot(range(min_samples, len(X_train), step_size), val_errors, label='Validation Error')
plt.xlabel('Training Set Size')
plt.ylabel('Mean Squared Error')
plt.title('Random Forest Regressor Learning Curve')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import joblib
import lightgbm as lgb
import catboost as cb
from sklearn.ensemble import RandomForestRegressor

# Assuming you have the data loaded in 'data' and the labels in 'target'

# Step 1: Train the models
rf_model = RandomForestRegressor()
rf_model.fit(data, target)

lgb_model = lgb.LGBMRegressor()
lgb_model.fit(data, target)

catboost_model = cb.CatBoostRegressor(silent=True, n_estimators=100)
catboost_model.fit(data, target)

# Step 2: Save the models to files using joblib, LightGBM's save_model(), and CatBoost's save_model()
rf_model_filename = 'random_forest_model.pkl'
lgb_model_filename = 'lgb_model.pkl'
catboost_model_filename = 'catboost_model.pkl'

joblib.dump(rf_model, rf_model_filename)
joblib.dump(lgb_model,lgb_model_filename)  # Corrected line for saving LightGBM model
joblib.dump(catboost_model,catboost_model_filename)
# Out:
# ['catboost_model.pkl']

# %%
import pickle
catboost_model = pickle.dump(model, open("catboost_model.pkl", 'wb')) #Saving the model

# %%
import joblib

# Step 3: Load the saved model from the file
rf_model = joblib.load('random_forest_model.pkl')
lgb_model = joblib.load('lgb_model.pkl')
catboost_model = joblib.load('catboost_model.pkl')

# %%
sample = {
"raw_values":[
    {
        "Temperature":32.47,
        "Humidity":59.26,
        "MQ7_analog":2867.0,
        "MQ9_analog":1539.0,
        "MG811_analog":4654.0,
        "MQ135_analog":2564.0,
    }
        ]
}

# %%
data = pd.DataFrame(sample["raw_values"])
import json

# %%
print("Random Forest Model",json.dumps(rf_model.predict(data).tolist()[0]))
print("Light GBM Model",json.dumps(lgb_model.predict(data).tolist()[0]))
print("Catboost Model",json.dumps(catboost_model.predict(data).tolist()[0]))
# Out:
# Random Forest Model 263.86083333333363
# Light GBM Model 113.08025233398489
# Catboost Model 1491.4802669980536
